# %%
import pandas as pd
from sklearn import datasets
df=pd.read_csv("Iris.csv")
df.hist(figsize=(10,10),bins=10)
# Out:
# array([[<Axes: title={'center': 'sepallength'}>,
#         <Axes: title={'center': 'sepalwidth'}>],
#        [<Axes: title={'center': 'petallength'}>,
#         <Axes: title={'center': 'petalwidth'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
df.petalwidth.plot.density(color='green')
plt.title('Density plot=petalwidth')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7))
df=pd.read_csv("Iris.csv")
plt.boxplot(df['sepalwidth'])
plt.show()

# %%
meandata=df.mean()
print(meandata)
# Out:
# sepallength    5.843333
# sepalwidth     3.054000
# petallength    3.758667
# petalwidth     1.198667
# dtype: float64

# %%
mediandata=df.median()
print(mediandata)
# Out:
# sepallength    5.80
# sepalwidth     3.00
# petallength    4.35
# petalwidth     1.30
# dtype: float64

# %%
modedata=df.mode()
print(modedata)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth
# 0          5.0         3.0          1.5         0.2
